# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np; np.random.seed(0)

# %%
df = pd.read_csv('cleaned_data.csv')

# %%
df = df.drop(['Unnamed: 0'], axis=1)

# %%
df['num_comp'] = df['Competitors'].apply(lambda x: len(x.split(',')) if x != '-1' else 0)

# %%
df['num_comp']
# Out:
# 0     0
# 1     3
# 2     0
# 3     3
# 4     0
# 5     0
# 6     0
# 7     0
# 8     0
# 9     0
# 10    0
# 11    0
# 12    3
# 13    0
# 14    0
# Name: num_comp, dtype: int64

# %%
df['company_txt']
# Out:
# 0                        ClearCut Analytics\n
# 1                                DentaQuest\n
# 2                                 SpawGlass\n
# 3     Pacific Northwest National Laboratory\n
# 4            Airlines Reporting Corporation\n
# 5                                     GEICO\n
# 6                          KCI Technologies\n
# 7                                      Otus\n
# 8                                 Celltheon\n
# 9                                      MMIT\n
# 10                         Acuity Insurance\n
# 11                 Aldeyra Therapeutics, Inc.
# 12                                      NFL\n
# 13                             NAVEX Global\n
# 14                           Beck's Hybrids\n
# Name: company_txt, dtype: object

# %%
df['company_txt'] = df['company_txt'].apply(lambda x: x.replace('\n', ''))

# %%
df['company_txt']
# Out:
# 0                        ClearCut Analytics
# 1                                DentaQuest
# 2                                 SpawGlass
# 3     Pacific Northwest National Laboratory
# 4            Airlines Reporting Corporation
# 5                                     GEICO
# 6                          KCI Technologies
# 7                                      Otus
# 8                                 Celltheon
# 9                                      MMIT
# 10                         Acuity Insurance
# 11               Aldeyra Therapeutics, Inc.
# 12                                      NFL
# 13                             NAVEX Global
# 14                           Beck's Hybrids
# Name: company_txt, dtype: object

# %%
df
# Out:
#                                             Job Title  \
# 0                                      Data Scientist
# 1            Senior Healthcare Analyst/Data Scientist
# 2                                       Data Engineer
# 3           Data Scientist - Statistics, Early Career
# 4                                       Data Engineer
# 5                               Senior Data Scientist
# 6                                           Scientist
# 7                                       Data Engineer
# 8   Scientist: Mammalian Cell Line Development- 3+...
# 9                                      Data Scientist
# 10       Senior Research Statistician- Data Scientist
# 11  Scientist/Senior Scientist Pharmacology-Transl...
# 12                 Director, Data Solutions Architect
# 13                                     Data Scientist
# 14                                  Ag Data Scientist
#
#               Salary Estimate  \
# 0   $80K-$120K(Employer est.)
# 1   $80K-$120K(Employer est.)
# 2   $80K-$120K(Employer est.)
# 3   $80K-$120K(Employer est.)
# 4   $80K-$120K(Employer est.)
# 5   $80K-$120K(Employer est.)
# 6   $80K-$120K(Employer est.)
# 7   $80K-$120K(Employer est.)
# 8   $80K-$120K(Employer est.)
# 9   $80K-$120K(Employer est.)
# 10  $80K-$120K(Employer est.)
# 11  $80K-$120K(Employer est.)
# 12  $80K-$120K(Employer est.)
# 13  $80K-$120K(Employer est.)
# 14  $80K-$120K(Employer est.)
#
#                                       Job Description  Rating  \
# 0   About ClearCut Analytics\nClearCut was founded...     5.0
# 1   This position is responsible for collaborating...     3.2
# 2   A Bit about Us\n\nOur organization was founded...     4.4
# 3   *Organization and Job ID**\nJob ID: 310918\n\n...     3.8
# 4   ARC is searching for a Data Engineer to join o...     3.9
# 5   GEICO’s Data Science team uses predictive anal...     3.3
# 6   Join us as we Rise to the Challenge\nAt KCI, w...     3.6
# 7   Otus is creating a culture of success while ma...     5.0
# 8   ABOUT CELLTHEON:\n\nLocated in the SF Bay Area...     4.0
# 9   Company Description\n\nMMIT is growing from th...     3.9
# 10  Acuity is seeking a Senior Research Statistici...     4.8
# 11  Company Summary:\nAldeyra Therapeutics is a bi...    -1.0
# 12  The Director, Data Solutions Architect will\nl...     3.9
# 13  It's fun to work in a company where people tru...     3.2
# 14  We're leaders. Innovators. Perfectionists. Con...     4.5
#
#                                   Company Name         Location  \
# 0                      ClearCut Analytics\n5.0      Chicago, IL
# 1                              DentaQuest\n3.2    Milwaukee, WI
# 2                               SpawGlass\n4.4      Houston, TX
# 3   Pacific Northwest National Laboratory\n3.8      Seattle, WA
# 4          Airlines Reporting Corporation\n3.9    Arlington, VA
# 5                                   GEICO\n3.3  Chevy Chase, MD
# 6                        KCI Technologies\n3.6       Sparks, MD
# 7                                    Otus\n5.0   Remote, Remote
# 8                               Celltheon\n4.0   Union City, CA
# 9                                    MMIT\n3.9      Yardley, PA
# 10                       Acuity Insurance\n4.8    Sheboygan, WI
# 11                  Aldeyra Therapeutics, Inc.    Lexington, MA
# 12                                    NFL\n3.9     New York, NY
# 13                           NAVEX Global\n3.2  Lake Oswego, OR
# 14                         Beck's Hybrids\n4.5      Atlanta, IN
#
#        Headquarters                    Size  Founded  \
# 0       Chicago, IL       1 to 50 employees     2016
# 1        Boston, MA  1001 to 5000 employees     2001
# 2       Houston, TX   501 to 1000 employees     1953
# 3      Richland, WA  1001 to 5000 employees     1965
# 4     Arlington, VA    201 to 500 employees     1984
# 5    Washington, DC        10000+ employees     1936
# 6       Glencoe, MD  1001 to 5000 employees     1988
# 7       Chicago, IL     51 to 200 employees     2014
# 8    Union City, CA       1 to 50 employees       -1
# 9       Yardley, PA    201 to 500 employees     1994
# 10    Sheboygan, WI  1001 to 5000 employees     1925
# 11               -1                      -1       -1
# 12     New York, NY  1001 to 5000 employees     1920
# 13  Lake Oswego, OR  1001 to 5000 employees     2012
# 14      Atlanta, IN   501 to 1000 employees     1937
#
#                  Type of ownership  ... avg_salary  \
# 0                Company - Private  ...      100.0
# 1                Company - Private  ...      100.0
# 2   Subsidiary or Business Segment  ...      100.0
# 3                       Government  ...      100.0
# 4                Company - Private  ...      100.0
# 5   Subsidiary or Business Segment  ...      100.0
# 6                Company - Private  ...      100.0
# 7                Company - Private  ...      100.0
# 8                Company - Private  ...      100.0
# 9                Company - Private  ...      100.0
# 10               Company - Private  ...      100.0
# 11                              -1  ...      100.0
# 12               Company - Private  ...      100.0
# 13               Company - Private  ...      100.0
# 14               Company - Private  ...      100.0
#
#                               company_txt job_state same_state  age  \
# 0                      ClearCut Analytics        IL          1    4
# 1                              DentaQuest        WI          0   19
# 2                               SpawGlass        TX          1   67
# 3   Pacific Northwest National Laboratory        WA          0   55
# 4          Airlines Reporting Corporation        VA          1   36
# 5                                   GEICO        MD          0   84
# 6                        KCI Technologies        MD          0   32
# 7                                    Otus    Remote          0    6
# 8                               Celltheon        CA          1    0
# 9                                    MMIT        PA          1   26
# 10                       Acuity Insurance        WI          1   95
# 11             Aldeyra Therapeutics, Inc.        MA          0    0
# 12                                    NFL        NY          1  100
# 13                           NAVEX Global        OR          1    8
# 14                         Beck's Hybrids        IN          1   83
#
#     python_yn  aws_yn excel_yn   R_yn  num_comp
# 0        True   False    False  False         0
# 1        True   False     True  False         3
# 2        True   False     True  False         0
# 3       False   False     True  False         3
# 4        True    True    False  False         0
# 5        True    True     True  False         0
# 6       False   False    False  False         0
# 7       False    True     True  False         0
# 8       False   False     True  False         0
# 9       False   False     True  False         0
# 10      False   False    False  False         0
# 11      False   False     True  False         0
# 12       True    True    False  False         3
# 13       True   False    False  False         0
# 14      False   False    False  False         0
#
# [15 rows x 26 columns]

# %%
df.describe()
# Out:
#           Rating      Founded  min_salary  max_salary  avg_salary  same_state  \
# count  15.000000    15.000000        15.0        15.0        15.0   15.000000
# mean    3.700000  1709.533333        80.0       120.0       100.0    0.600000
# std     1.431782   695.238691         0.0         0.0         0.0    0.507093
# min    -1.000000    -1.000000        80.0       120.0       100.0    0.000000
# 25%     3.450000  1930.500000        80.0       120.0       100.0    0.000000
# 50%     3.900000  1965.000000        80.0       120.0       100.0    1.000000
# 75%     4.450000  1997.500000        80.0       120.0       100.0    1.000000
# max     5.000000  2016.000000        80.0       120.0       100.0    1.000000
#
#               age   num_comp
# count   15.000000  15.000000
# mean    41.000000   0.600000
# std     36.588445   1.242118
# min      0.000000   0.000000
# 25%      7.000000   0.000000
# 50%     32.000000   0.000000
# 75%     75.000000   0.000000
# max    100.000000   3.000000

# %%
df.Rating.hist()
# Out:
# <AxesSubplot:>

# %%
df.avg_salary.hist()
# Out:
# <AxesSubplot:>

# %%
df.age.hist()
# Out:
# <AxesSubplot:>

# %%
df.desc_len.hist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-244b65252270> in <module>
# ----> 1 df.desc_len.hist()
#
# c:\users\aaron\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'desc_len'

# %%
df[['age', 'avg_salary', 'Rating']].corr()
# Out:
#                  age  avg_salary    Rating
# age         1.000000         NaN  0.297786
# avg_salary       NaN         NaN       NaN
# Rating      0.297786         NaN  1.000000

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(df[['age', 'avg_salary', 'Rating']].corr(), vmax=.3, center=0, cmap="YlGnBu",
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
data = np.random.randn(50, 20)
ax = sns.heatmap(data, xticklabels=2, yticklabels=False)
